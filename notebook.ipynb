# %%
import pandas as pd
df = pd.read_csv("data/raw/general_stock_data/test/all_stocks_test.csv")
df.head(10)
# Out:
#          Date       Close        High         Low        Open     Volume  \
# 0  2023-07-18  293.339996  295.260010  286.010010  290.149994  112120300
# 1  2023-07-18  236.778122  239.148154  233.739342  239.069493    7674000
# 2  2023-07-19  192.946991  196.042440  190.524016  190.969062   80507300
# 3  2023-07-19  135.360001  135.990005  132.529999  133.389999   54531000
# 4  2023-07-19  121.945496  124.617215  121.637605  123.941836   22313800
# 5  2023-07-19  147.160843  148.076729  145.224141  145.729781   12510000
# 6  2023-07-19  314.285828  316.941243  308.825761  311.322076   21763700
# 7  2023-07-19  349.069366  356.324446  346.474071  355.626473   39732900
# 8  2023-07-19  477.589996  485.000000  470.000000  476.859985   20996500
# 9  2023-07-19   47.048046   47.788592   46.713253   47.434809  427502000
#
#   Ticker
# 0   TSLA
# 1      V
# 2   AAPL
# 3   AMZN
# 4   GOOG
# 5    JPM
# 6   META
# 7   MSFT
# 8   NFLX
# 9   NVDA

# %%
df = df.drop(index=0)
df
# Out:
#             Date               Close                High                 Low  \
# 1     2015-01-05  25.471742630004883   25.99022894167243  25.431593179097373
# 2     2015-01-06  24.881383895874023  25.586000659489585  24.836278093168957
# 3     2015-01-07  24.838754653930664  25.143302703865842  24.766880024812913
# 4     2015-01-08  24.917072296142578   24.95672687186251  24.338112456906735
# 5     2015-01-09  24.594383239746094   25.02810541050365  24.525978431139116
# ...          ...                 ...                 ...                 ...
# 2143  2023-07-11  117.01444244384766  117.52639866598123  115.14555422606084
# 2144  2023-07-12  118.91315460205078  120.24523274981125  118.29681552192054
# 2145  2023-07-13  124.09236907958984  124.59438225459672  120.34464213296195
# 2146  2023-07-14  124.95723724365234   126.3390231443501  124.16196898420087
# 2147  2023-07-17  124.32101440429688  126.52789757337163  123.76432588752567
#
#                     Open    Volume Ticker
# 1     25.937189952759287  41196796   GOOG
# 2     25.527756931401218  57998800   GOOG
# 3     25.131207622241284  41301082   GOOG
# 4      24.68459606613181  67071641   GOOG
# 5     25.020176012006146  41427428   GOOG
# ...                  ...       ...    ...
# 2143  116.07005909420425  18286600   GOOG
# 2144  118.59504582166682  22059600   GOOG
# 2145  120.82180910287565  31535900   GOOG
# 2146  124.39060566987206  20499800   GOOG
# 2147  125.31510537528102  20675300   GOOG
#
# [2147 rows x 7 columns]

# %%
import yfinance as yf
df = yf.download("GOOG", start="2020-01-01", end="2023-01-01")
df.reset_index(inplace=True)
# Flatten multi-level columns
df.columns = [col[0] if col[1] == '' else f"{col[0]}" for col in df.columns.values]
df['Ticker'] = "GOOG"
df.head(10)
# Out:
# C:\Users\tanus\AppData\Local\Temp\ipykernel_25528\3227414792.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("GOOG", start="2020-01-01", end="2023-01-01")
# [*********************100%***********************]  1 of 1 completed
#         Date      Close       High        Low       Open    Volume Ticker
# 0 2020-01-02  67.903824  67.942060  66.621598  66.621598  28132000   GOOG
# 1 2020-01-03  67.570595  68.158574  66.819933  66.934945  23728000   GOOG
# 2 2020-01-06  69.236687  69.350403  67.041209  67.041209  34646000   GOOG
# 3 2020-01-07  69.193481  69.672700  69.046485  69.421921  30054000   GOOG
# 4 2020-01-08  69.738754  70.099286  69.069332  69.130907  30560000   GOOG
# 5 2020-01-09  70.508987  70.881439  70.034232  70.545738  30018000   GOOG
# 6 2020-01-10  71.000633  71.258815  70.435500  70.892865  36414000   GOOG
# 7 2020-01-13  71.472397  71.536457  70.816387  71.318452  33046000   GOOG
# 8 2020-01-14  71.057739  71.600026  70.933096  71.461478  31178000   GOOG
# 9 2020-01-15  71.470894  71.579897  71.024448  71.024448  25654000   GOOG

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Date, )        756 non-null    datetime64[ns]
#  1   (Close, GOOG)   756 non-null    float64
#  2   (High, GOOG)    756 non-null    float64
#  3   (Low, GOOG)     756 non-null    float64
#  4   (Open, GOOG)    756 non-null    float64
#  5   (Volume, GOOG)  756 non-null    int64
#  6   (Ticker, )      756 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 41.5+ KB

# %%
from stock_prediction.utils.main_utils import MainUtils
train_data = MainUtils.load_object("data/interim/stock_data/test/AAPL_test_processed.pkl")
train_data[:10]
# Out:
# [ 2025-09-09 19:48:36,198 ] root - INFO - Entered the load_object method of MainUtils class
# [ 2025-09-09 19:48:36,227 ] root - INFO - Exited the load_object method of MainUtils class
# array([[9.97514686e-01, 9.99134884e-01, 1.00356408e+00, 9.98498318e-01,
#         2.72609323e-02, 1.91592133e+02],
#        [9.96069441e-01, 1.02163654e+00, 1.00490765e+00, 1.00641104e+00,
#         7.94488530e-02, 1.92946991e+02],
#        [1.00757210e+00, 1.01148199e+00, 1.00403141e+00, 9.95032801e-01,
#         4.55531313e-02, 1.90998749e+02],
#        [1.00184979e+00, 1.00282745e+00, 9.96611318e-01, 9.88159604e-01,
#         6.55906454e-02, 1.89821884e+02],
#        [9.97861329e-01, 1.00248117e+00, 1.00257069e+00, 9.92837891e-01,
#         2.25467186e-02, 1.90622925e+02],
#        [9.97398919e-01, 9.99769417e-01, 1.00648524e+00, 9.97862836e-01,
#         9.43523058e-03, 1.91483322e+02],
#        [9.99364117e-01, 1.00669301e+00, 1.00882228e+00, 1.00294553e+00,
#         2.59387042e-02, 1.92353607e+02],
#        [1.01294765e+00, 1.01569378e+00, 1.00432348e+00, 9.95552522e-01,
#         2.59197528e-02, 1.91087738e+02],
#        [1.00514422e+00, 1.01240496e+00, 1.01361307e+00, 1.01062727e+00,
#         2.72661156e-02, 1.93668915e+02],
#        [1.01317891e+00, 1.01159741e+00, 1.02015696e+00, 1.01420846e+00,
#         1.19311528e-02, 1.94282104e+02]])

# %%
# #to train model in colab
# # ==============================================================================
# # Cell 1: Setup and Imports
# # ==============================================================================

# !pip install yfinance

# import sys
# import os
# import numpy as np
# import pandas as pd
# import yfinance as yf
# from sklearn.preprocessing import MinMaxScaler
# import tensorflow as tf # <-- FIX: tensorflow is now imported
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Dropout
# from tensorflow.keras.callbacks import ModelCheckpoint

# # Check for GPU
# print("GPU available:", len(tf.config.list_physical_devices('GPU')) > 0)


# # ==============================================================================
# # Cell 2: Configuration and Parameters
# # ==============================================================================

# # Model parameters
# lstm_params = {
#     "units": 128,
#     "dropout": 0.2,
#     "dense_units": 1,
#     "activation": "relu",
#     "loss": "mean_squared_error",
#     "optimizer": "adam",
#     "batch_size": 32,
#     "epochs": 50,
#     "validation_split": 0.1,
#     "time_step": 60 
# }

# # Data parameters
# data_params = {
#     "tickers": ["AAPL", "MSFT", "GOOG", "AMZN", "TSLA", "META", "NFLX", "NVDA", "JPM", "V"],
#     "test_size": 0.2,
#     "start_date": "2015-01-01",
#     "end_date": "2023-12-31"
# }


# # ==============================================================================
# # Cell 3: Helper Functions
# # ==============================================================================

# def fetch_stock_data(ticker: str) -> pd.DataFrame:
#     """Fetch stock data from Yahoo Finance."""
#     df = yf.download(ticker, start=data_params["start_date"], end=data_params["end_date"])
#     df.reset_index(inplace=True)
#     df.columns = [col[0] if col[1] == '' else f"{col[0]}" for col in df.columns.values]
#     return df

# def preprocess_stock_data(train_data: pd.DataFrame, test_data: pd.DataFrame, target_column: str = 'Close'):
#     """
#     Transforms train/test stock data:
#     - Drops non-numeric cols (Date, Ticker, etc.)
#     - Scales features with MinMaxScaler
#     - Returns numpy arrays with scaled features + original target
#     """
#     X_train = train_data.drop(columns=[target_column], errors="ignore")
#     y_train = train_data[target_column]

#     X_test = test_data.drop(columns=[target_column], errors="ignore")
#     y_test = test_data[target_column]

#     X_train = X_train.apply(pd.to_numeric, errors="coerce").dropna(axis=1, how="all")
#     X_test = X_test.apply(pd.to_numeric, errors="coerce").dropna(axis=1, how="all")

#     scaler = MinMaxScaler()
#     X_train_scaled = scaler.fit_transform(X_train)
#     X_test_scaled = scaler.transform(X_test)

#     train_arr = np.c_[X_train_scaled, np.array(y_train)]
#     test_arr = np.c_[X_test_scaled, np.array(y_test)]

#     return train_arr, test_arr

# def reshape_for_lstm(data, sequence_length):
#     """
#     Convert processed stock data into sequences for LSTM.
#     Last column is assumed to be the target.
#     """
#     X, y = [], []
#     for i in range(len(data) - sequence_length):
#         X.append(data[i:i + sequence_length, :-1])
#         y.append(data[i + sequence_length, -1])
#     return np.array(X), np.array(y)

# def build_lstm_model(input_shape, units, dropout, dense_units, activation, optimizer, loss):
#     """Build and compile a multi-layer LSTM model."""
#     model = Sequential([
#         LSTM(units=units, return_sequences=True, input_shape=input_shape),
#         Dropout(dropout),
#         LSTM(units=units),
#         Dropout(dropout),
#         Dense(units=dense_units, activation=activation)
#     ])
#     model.compile(optimizer=optimizer, loss=loss)
#     return model


# # ==============================================================================
# # Cell 4: Main Training and Execution
# # ==============================================================================

# def main():
#     all_stocks_data = []

#     # Create directories
#     os.makedirs("./artifacts/models/best_models", exist_ok=True)
#     os.makedirs("./artifacts/models/final_models", exist_ok=True)

#     # --- Train on each individual stock ---
#     for ticker in data_params["tickers"]:
#         print(f"\n--- Processing Ticker: {ticker} ---")
#         try:
#             df = fetch_stock_data(ticker)
#             if df.empty:
#                 print(f"No data found for {ticker}. Skipping.")
#                 continue

#             # Split data
#             split_idx = int(len(df) * (1 - data_params["test_size"]))
#             train_df, test_df = df.iloc[:split_idx], df.iloc[split_idx:]
            
#             train_data, test_data = preprocess_stock_data(train_df, test_df)
            
#             sequence_length = lstm_params["time_step"]
#             X_train, y_train = reshape_for_lstm(train_data, sequence_length)
#             X_test, y_test = reshape_for_lstm(test_data, sequence_length)

#             if X_train.shape[0] == 0 or X_test.shape[0] == 0:
#                 print(f"Not enough data to create sequences for {ticker}. Skipping.")
#                 continue

#             num_features = X_train.shape[2]
            
#             model = build_lstm_model(
#                 input_shape=(sequence_length, num_features),
#                 units=lstm_params['units'],
#                 dropout=lstm_params['dropout'],
#                 dense_units=lstm_params['dense_units'],
#                 activation=lstm_params['activation'],
#                 optimizer=lstm_params['optimizer'],
#                 loss=lstm_params['loss']
#             )

#             # Define checkpoint and train
#             checkpoint_path = os.path.join("./artifacts/models/best_models", f"best_model_{ticker}.h5")
#             checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)

#             print(f"Training model for {ticker}...")
#             model.fit(
#                 X_train, y_train,
#                 validation_data=(X_test, y_test),
#                 epochs=lstm_params['epochs'],
#                 batch_size=lstm_params['batch_size'],
#                 callbacks=[checkpoint],
#                 verbose=2
#             )

#             final_model_path = os.path.join("./artifacts/models/final_models", f"final_model_{ticker}.h5")
#             model.save(final_model_path)
#             print(f"Final LSTM model saved for {ticker} at {final_model_path}")
            
#             # Append data for generalized model
#             df['Ticker'] = ticker
#             all_stocks_data.append(df)

#         except Exception as e:
#             print(f"Error processing {ticker}: {e}")
#             continue

#     # --- Train on the generalized stock data ---
#     if all_stocks_data:
#         print("\n--- Initiating training for generalized stock data ---")
#         general_df = pd.concat(all_stocks_data, axis=0)
#         general_df = general_df.sort_values(by=["Date", "Ticker"]).reset_index(drop=True)

#         split_idx = int(len(general_df) * (1 - data_params["test_size"]))
#         general_train_df, general_test_df = general_df.iloc[:split_idx], general_df.iloc[split_idx:]
        
#         general_train_data, general_test_data = preprocess_stock_data(general_train_df, general_test_df)

#         sequence_length = lstm_params["time_step"]
#         X_train_gen, y_train_gen = reshape_for_lstm(general_train_data, sequence_length)
#         X_test_gen, y_test_gen = reshape_for_lstm(general_test_data, sequence_length)

#         num_features = X_train_gen.shape[2]

#         model_gen = build_lstm_model(
#             input_shape=(sequence_length, num_features),
#             units=lstm_params['units'],
#             dropout=lstm_params['dropout'],
#             dense_units=lstm_params['dense_units'],
#             activation=lstm_params['activation'],
#             optimizer=lstm_params['optimizer'],
#             loss=lstm_params['loss']
#         )
        
#         checkpoint_path_gen = os.path.join("./artifacts/models/best_models", "best_model_general.h5")
#         checkpoint_gen = ModelCheckpoint(checkpoint_path_gen, monitor='val_loss', save_best_only=True, verbose=1)

#         print("Training generalized model...")
#         model_gen.fit(
#             X_train_gen, y_train_gen,
#             validation_data=(X_test_gen, y_test_gen),
#             epochs=lstm_params['epochs'],
#             batch_size=lstm_params['batch_size'],
#             callbacks=[checkpoint_gen],
#             verbose=2
#         )
#         final_model_path_gen = os.path.join("./artifacts/models/final_models", "final_model_general.h5")
#         model_gen.save(final_model_path_gen)
#         print(f"Final LSTM model saved for generalized data at {final_model_path_gen}")

#     print("All model training completed successfully.")

# if __name__ == "__main__":
#     main()

# %%
import pandas as pd
df = pd.read_csv("data/raw/general_stock_data/test/all_stocks_test.csv")
df.head(10)
